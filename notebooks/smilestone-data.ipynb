# %% [markdown]
# # Exploratory Data Analysis
# In this notebook, we will do some general exploration of the respective datasets to get a feel for what would be the best way to build the predictive model. Woof woof!

# %% [markdown]
# ## Project Setup

# %%
# Importing the necessary libraries
import pandas as pd

# %%
# Loading the raw dataset
df_raw = pd.read_csv('../data/raw.csv')

# %% [markdown]
# ## Raw Dataset Exploration

# %%
# Viewing the first few rows of the dataset
df_raw.head()
# Out:
#             Name Category  Rating Flickable Episode Number  \
# 0    Zoolander 2    Movie     7.0       Yes             10
# 1           Dope    Movie     8.5       Yes             11
# 2  The Big Short    Movie     8.0       Yes             12
# 3       Deadpool    Movie    10.0       Yes             13
# 4          Vinyl  TV Show     7.5       Yes             15
#
#                                                Notes
# 0                            The very first flickin!
# 1                                                NaN
# 2  Gary had to read Caelan's notes since Caelan h...
# 3                                                NaN
# 4                                                NaN

# %%
# Dropping the "Notes" column as it is just used for fun and will not be applicable to the model
df_raw.drop(columns = ['Notes'], inplace = True)

# %%
# Keeping only reviews from the main show
df_raw = df_raw[df_raw['Episode Number'].str.startswith('M') == False]

# %%
# Changing datatype of "Episode Number" from object to int
df_raw['Episode Number'] = df_raw['Episode Number'].astype(int)

# %% [markdown]
# ## The Two Banger

# %%
# Getting all the reviews between the first and second banger
two_banger = df_raw[df_raw['Episode Number'] > 69]

# %%
# Viewing general info about the two banger
two_banger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89 entries, 107 to 195
# Data columns (total 5 columns):
# Name              89 non-null object
# Category          89 non-null object
# Rating            88 non-null float64
# Flickable         89 non-null object
# Episode Number    89 non-null int32
# dtypes: float64(1), int32(1), object(3)
# memory usage: 2.8+ KB

# %%
# Viewing the dispersion of category types
two_banger['Category'].value_counts()
# Out:
# Movie      50
# Food       14
# Other      13
# TV Show     8
# Person      4
# Name: Category, dtype: int64

# %%
# Viewing all people rated in this timeframe
two_banger[two_banger['Category'] == 'Person']
# Out:
#                     Name Category  Rating Flickable  Episode Number
# 108  Neil DeGrasse Tyson   Person     9.5       Yes              72
# 109             Bill Nye   Person     7.0       Yes              72
# 152        Michael Biehn   Person    10.0       Yes             100
# 163  Caelan's little bro   Person    10.0       Yes             114

# %%
# Viewing perfect 10s
two_banger[two_banger['Rating'] == 10]
# Out:
#                                        Name Category  Rating Flickable  \
# 115                                   Pizza     Food    10.0       Yes
# 118                         Summer vacation    Other    10.0       Yes
# 119  Sending caelan free Boston baked beans    Other    10.0       Yes
# 132               Rick and Marty (Season 1)  TV Show    10.0       Yes
# 150        Bartenders on the Carolla cruise    Other    10.0       Yes
# 152                           Michael Biehn   Person    10.0       Yes
# 163                     Caelan's little bro   Person    10.0       Yes
#
#      Episode Number
# 115              75
# 118              75
# 119              81
# 132              86
# 150             100
# 152             100
# 163             114

# %%
# Viewing perfect 0s
two_banger[two_banger['Rating'] == 0]
# Out:
#                 Name Category  Rating Flickable  Episode Number
# 111          Sonic's     Food     0.0        No              73
# 144  Whatchamacallit     Food     0.0        No              96

# %%
# Viewing low scores
two_banger[two_banger['Rating'] <= 3]
# Out:
#                           Name Category  Rating Flickable  Episode Number
# 111                    Sonic's     Food     0.0        No              73
# 130                       Life    Movie     3.0        No              86
# 134                 Death Note    Movie     0.5        No              87
# 141             Reese's Pieces     Food     3.0        No              96
# 142  Reese's Peanut Butter Cup     Food     3.0       Yes              96
# 143                       Twix     Food     2.0        No              96
# 144            Whatchamacallit     Food     0.0        No              96
# 153    Mixed berry e-cigarette    Other     3.0        No             100
# 160    The Cloverfield Paradox    Movie     2.0        No             109
# 173                Kidney bean     Food     2.0        No             126
# 175               Annihilation    Movie     3.0        No             128
# 189                     Jigsaw    Movie     2.0        No             135

# %% [markdown]
# ## The Three Banger

# %%
# Getting all the reviews between the second and third bangers
three_banger = df_raw[(df_raw['Episode Number'] >= (69*2)) & (df_raw['Episode Number'] < (69*3))]

# %%
three_banger
# Out:
#                                                   Name Category  Rating  \
# 194                                 The Shape of Water    Movie     7.5
# 195                                      Hold the Dark    Movie     5.0
# 196                                     A Star is Born    Movie     9.0
# 197                               Jack Ryan (Season 1)  TV Show     8.0
# 198                         You Were Never Really Here   Movie      5.0
# 199                                        Outlaw King    Movie     7.5
# 200                                         Candy cane     Food     6.0
# 201                                          Bodyguard  TV Show     7.5
# 202                           The Christmas Chronicles    Movie     8.0
# 203                                  Bohemian Rhapsody    Movie     8.0
# 204                                       Bandersnatch    Movie     9.6
# 205                                           Bird Box    Movie     7.5
# 206                                              Polar    Movie     5.2
# 207                                            Kingdom  TV Show     8.8
# 208                                 Alita Battle Angel    Movie     8.6
# 209  The experience of watching Alita battle Angel ...    Other    10.0
# 210                         Resident Evil 2 Remastered    Other     9.4
# 211                                            Donovan   Person     9.0
# 212                                        Laxi (band)    Other     9.6
# 213                                 The band name Laxi    Other     8.0
# 214                                    Triple Frontier    Movie     4.7
# 215                                           The Dirt    Movie     6.9
# 216                                     The Highwaymen    Movie     3.0
# 217                                        The Silence    Movie     0.9
# 218                                  Avengers: Endgame    Movie     9.7
# 219                                Pet Sematary (2019)    Movie     4.6
# 220                   Game of Thrones (full TV series)  TV Show     8.9
# 221                                     The Perfection    Movie     6.0
# 222                         Bad Times at the El Royale    Movie     7.4
# 223                                         Rocketman     Movie     9.3
# 224                     Isla (Caelan's first daughter)   Person     9.0
# 225                                     Gone Baby Gone    Movie     8.0
# 226                                   Having pneumonia    Other     0.0
# 227                  Dave Chappelle: Sticks and Stones    Other     9.1
# 228                         Jim Gaffigan: Quality Time    Other     9.1
# 229                                           Ad Astra    Movie     6.8
# 230                                              Joker    Movie     9.6
# 231                                          El Camino    Movie     6.1
# 232                                           Midsomer    Movie     3.2
# 233                                           The King    Movie     7.7
# 234                                    Midnight Family    Movie     6.1
# 235                                Watchmen (Season 1)  TV Show     8.8
# 236                                Screwdriver (drink)     Food     3.4
# 237                          Von's (the grocery store)    Other     4.9
# 238                                Grass (like a lawn)    Other     8.9
# 239                               The word "facetious"    Other     9.4
# 240                                       South Dakota    Other     3.2
#
#     Flickable  Episode Number
# 194       Yes             138
# 195       Yes             139
# 196       Yes             140
# 197       Yes             142
# 198        No             143
# 199       Yes             146
# 200       Yes             147
# 201       Yes             147
# 202       Yes             149
# 203       Yes             150
# 204       Yes             151
# 205       Yes             152
# 206       Yes             155
# 207       Yes             156
# 208       Yes             157
# 209       Yes             157
# 210       Yes             160
# 211       Yes             160
# 212       Yes             160
# 213       Yes             160
# 214        No             162
# 215       Yes             163
# 216        No             165
# 217        No             166
# 218       Yes             169
# 219        No             170
# 220       Yes             171
# 221       Yes             172
# 222       Yes             174
# 223       Yes             177
# 224       Yes             177
# 225       Yes             180
# 226        No             182
# 227       Yes             183
# 228       Yes             183
# 229       Yes             186
# 230       Yes             192
# 231       Yes             192
# 232        No             192
# 233       Yes             197
# 234       Yes             198
# 235       Yes             199
# 236        No             204
# 237        No             204
# 238       Yes             204
# 239       Yes             204
# 240        No             204

# %%
# Viewing general info about the three banger
three_banger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 194 to 240
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            47 non-null     object
#  1   Category        47 non-null     object
#  2   Rating          47 non-null     float64
#  3   Flickable       47 non-null     object
#  4   Episode Number  47 non-null     int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.2+ KB

# %%
# Viewing the dispersion of category types
three_banger['Category'].value_counts()
# Out:
# Movie      26
# Other      11
# TV Show     5
# Person      2
# Food        2
# Movie       1
# Name: Category, dtype: int64

# %%
# Viewing all people rated in this timeframe
three_banger[three_banger['Category'] == 'Person']
# Out:
#                                Name Category  Rating Flickable  Episode Number
# 211                         Donovan   Person     9.0       Yes             160
# 224  Isla (Caelan's first daughter)   Person     9.0       Yes             177

# %%
# Viewing perfect 10s
three_banger[three_banger['Rating'] == 10]
# Out:
#                                                   Name Category  Rating  \
# 209  The experience of watching Alita battle Angel ...    Other    10.0
#
#     Flickable  Episode Number
# 209       Yes             157

# %%
# Viewing perfect 0s
three_banger[three_banger['Rating'] == 0]
# Out:
#                  Name Category  Rating Flickable  Episode Number
# 226  Having pneumonia    Other     0.0        No             182

# %%
# Viewing low scores
three_banger[three_banger['Rating'] <= 3]
# Out:
#                  Name Category  Rating Flickable  Episode Number
# 216    The Highwaymen    Movie     3.0        No             165
# 217       The Silence    Movie     0.9        No             166
# 226  Having pneumonia    Other     0.0        No             182

# %%
# Viewing high scores
three_banger[three_banger['Rating'] >= 9.5]
# Out:
#                                                   Name Category  Rating  \
# 204                                       Bandersnatch    Movie     9.6
# 209  The experience of watching Alita battle Angel ...    Other    10.0
# 212                                        Laxi (band)    Other     9.6
# 218                                  Avengers: Endgame    Movie     9.7
# 230                                              Joker    Movie     9.6
#
#     Flickable  Episode Number
# 204       Yes             151
# 209       Yes             157
# 212       Yes             160
# 218       Yes             169
# 230       Yes             192
